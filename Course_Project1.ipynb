# %%
import math
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !mkdir dataset

# %%
# !unzip dataset/archive1.zip -d dataset/
# Out:
# Archive:  dataset/archive1.zip
#   inflating: dataset/Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv

# %%
df = pd.read_csv('dataset/Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv')
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2011     2011           AL      Alabama
# 1       2011     2011           AL      Alabama
# 2       2011     2011           AL      Alabama
# 3       2011     2011           AL      Alabama
# 4       2011     2011           AL      Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# ...

# %%
df.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
df.shape
# Out:
# (53392, 33)

# %%
df.describe()
# Out:
#           YearStart       YearEnd  Data_Value_Unit    Data_Value  \
# count  53392.000000  53392.000000              0.0  48346.000000
# mean    2013.281465   2013.281465              NaN     31.156681
# std        1.693300      1.693300              NaN     10.247033
# min     2011.000000   2011.000000              NaN      0.900000
# 25%     2012.000000   2012.000000              NaN     24.100000
# 50%     2013.000000   2013.000000              NaN     30.700000
# 75%     2015.000000   2015.000000              NaN     37.000000
# max     2016.000000   2016.000000              NaN     77.600000
#
#        Data_Value_Alt  Low_Confidence_Limit  High_Confidence_Limit   \
# count    48346.000000          48346.000000            48346.000000
# mean        31.156681             26.892227               35.989997
# std         10.247033             10.038584               11.205813
# min          0.900000              0.300000                3.000000
# ...

# %%
df.isnull().sum()
# Out:
# YearStart                         0
# YearEnd                           0
# LocationAbbr                      0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit               53392
# Data_Value_Type                   0
# Data_Value                     5046
# Data_Value_Alt                 5046
# Data_Value_Footnote_Symbol    48346
# Data_Value_Footnote           48346
# Low_Confidence_Limit           5046
# High_Confidence_Limit          5046
# Sample_Size                    5046
# Total                         51485
# Age(years)                    41954
# Education                     45764
# Gender                        49578
# Income                        40043
# Race/Ethnicity                38136
# GeoLocation                    1008
# ClassID                           0
# TopicID                           0
# ...

# %%
df.isnull().sum() * 100/len(df)
# Out:
# YearStart                       0.000000
# YearEnd                         0.000000
# LocationAbbr                    0.000000
# LocationDesc                    0.000000
# Datasource                      0.000000
# Class                           0.000000
# Topic                           0.000000
# Question                        0.000000
# Data_Value_Unit               100.000000
# Data_Value_Type                 0.000000
# Data_Value                      9.450854
# Data_Value_Alt                  9.450854
# Data_Value_Footnote_Symbol     90.549146
# Data_Value_Footnote            90.549146
# Low_Confidence_Limit            9.450854
# High_Confidence_Limit           9.450854
# Sample_Size                     9.450854
# Total                          96.428304
# Age(years)                     78.577315
# Education                      85.713215
# Gender                         92.856608
# Income                         74.998127
# Race/Ethnicity                 71.426431
# ...

# %%
df.drop(['YearEnd', 'LocationAbbr', 'Datasource','Topic', 'Data_Value_Unit', 'Data_Value_Type', 'Data_Value_Footnote',
         'Total', 'Data_Value_Footnote_Symbol', 'GeoLocation', 'DataValueTypeID','StratificationID1', 'ClassID',
         'TopicID', 'QuestionID', 'LocationID', 'StratificationCategoryId1'], axis=1, inplace=True)
df.head()
# Out:
#    YearStart LocationDesc                    Class  \
# 0       2011      Alabama  Obesity / Weight Status
# 1       2011      Alabama  Obesity / Weight Status
# 2       2011      Alabama  Obesity / Weight Status
# 3       2011      Alabama  Obesity / Weight Status
# 4       2011      Alabama  Obesity / Weight Status
#
#                                             Question  Data_Value  \
# 0  Percent of adults aged 18 years and older who ...        32.0
# 1  Percent of adults aged 18 years and older who ...        32.3
# 2  Percent of adults aged 18 years and older who ...        31.8
# 3  Percent of adults aged 18 years and older who ...        33.6
# 4  Percent of adults aged 18 years and older who ...        32.8
#
#    Data_Value_Alt  Low_Confidence_Limit  High_Confidence_Limit   Sample_Size  \
# 0            32.0                  30.5                    33.5       7304.0
# 1            32.3                  29.9                    34.7       2581.0
# ...

# %%
df.drop(['Sample_Size'], axis=1, inplace=True)
df.head()
# Out:
#    YearStart LocationDesc                    Class  \
# 0       2011      Alabama  Obesity / Weight Status
# 1       2011      Alabama  Obesity / Weight Status
# 2       2011      Alabama  Obesity / Weight Status
# 3       2011      Alabama  Obesity / Weight Status
# 4       2011      Alabama  Obesity / Weight Status
#
#                                             Question  Data_Value  \
# 0  Percent of adults aged 18 years and older who ...        32.0
# 1  Percent of adults aged 18 years and older who ...        32.3
# 2  Percent of adults aged 18 years and older who ...        31.8
# 3  Percent of adults aged 18 years and older who ...        33.6
# 4  Percent of adults aged 18 years and older who ...        32.8
#
#    Data_Value_Alt  Low_Confidence_Limit  High_Confidence_Limit  Age(years)  \
# 0            32.0                  30.5                    33.5        NaN
# 1            32.3                  29.9                    34.7        NaN
# ...

# %%
class_counts = df['Class'].value_counts()

# Pie chart labels and sizes
labels = class_counts.index
sizes = class_counts.values

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Classes')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Show the pie chart
plt.show()

# %%
questions = df['Question'].value_counts()
questions
# Out:
# Percent of adults aged 18 years and older who have obesity                                                                                                                                                                                               8960
# Percent of adults aged 18 years and older who have an overweight classification                                                                                                                                                                          8960
# Percent of adults who engage in no leisure-time physical activity                                                                                                                                                                                        8932
# ...

# %%
question_counts = df['Question'].value_counts()
size = question_counts.values
labels = [
    "Obesity",
    "Overweight",
    "No Physical Activity",
    "Low Vegetable Consumption",
    "Muscle-Strengthening",
    "Moderate Aerobic Activity",
    "Moderate Aerobic + Muscle-Strengthening",
    "High Aerobic Activity",
    "Low Fruit Consumption"
]

# Create a pie chart
plt.figure(figsize=(10, 10))
plt.pie(size , labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Percentage of Adults for Different Activities')
plt.axis('equal')

# Show the pie chart
plt.show()

# %%
val_to_drop = 'Obesity / Weight Status'
filter_data = df[df['Class'] != val_to_drop]
unique_values = filter_data['Class'].nunique()
unique_values
# Out:
# 2

# %%
val_to_drop1 = 'Physical Activity'
filter_data1 = filter_data[filter_data['Class'] != val_to_drop1]
unique_values = filter_data1['Class'].nunique()
unique_values
# Out:
# 1

# %%
filter_data1.columns
# Out:
# Index(['YearStart', 'LocationDesc', 'Class', 'Question', 'Data_Value',
#        'Data_Value_Alt', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Age(years)', 'Education', 'Gender', 'Income', 'Race/Ethnicity',
#        'StratificationCategory1', 'Stratification1'],
#       dtype='object')

# %%
filter_data1.drop(['Data_Value_Alt'], axis=1, inplace=True)
filter_data1
# Out:
# <ipython-input-18-aee6306a8b70>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_data1.drop(['Data_Value_Alt'], axis=1, inplace=True)
#        YearStart LocationDesc                  Class  \
# 56          2011      Alabama  Fruits and Vegetables
# 57          2011      Alabama  Fruits and Vegetables
# 58          2011      Alabama  Fruits and Vegetables
# 59          2011      Alabama  Fruits and Vegetables
# 60          2011      Alabama  Fruits and Vegetables
# ...          ...          ...                    ...
# 38204       2015  Puerto Rico  Fruits and Vegetables
# 38205       2015  Puerto Rico  Fruits and Vegetables
# 38206       2015  Puerto Rico  Fruits and Vegetables
# 38207       2015  Puerto Rico  Fruits and Vegetables
# 38208       2015  Puerto Rico  Fruits and Vegetables
# ...

# %%
# Calculate the count of each unique value in 'LocationDesc' column
location_counts = filter_data1['LocationDesc'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=location_counts.index, y=location_counts.values)
plt.xticks(rotation=90)
plt.xlabel('LocationDesc')
plt.ylabel('Count')
plt.title('Count of Unique Values in LocationDesc')
plt.show()

# %%
numeric_data = filter_data1.select_dtypes(include = ['int64','float64'])
filter_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8844 entries, 56 to 38208
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   YearStart                8844 non-null   int64
#  1   LocationDesc             8844 non-null   object
#  2   Class                    8844 non-null   object
#  3   Question                 8844 non-null   object
#  4   Data_Value               7994 non-null   float64
#  5   Low_Confidence_Limit     7994 non-null   float64
#  6   High_Confidence_Limit    7994 non-null   float64
#  7   Age(years)               1892 non-null   object
#  8   Education                1264 non-null   object
#  9   Gender                   632 non-null    object
#  10  Income                   2212 non-null   object
#  11  Race/Ethnicity           2528 non-null   object
#  12  StratificationCategory1  8844 non-null   object
#  13  Stratification1          8844 non-null   object
# ...

# %%
filter_data1 = pd.get_dummies(filter_data1, columns=['Age(years)', 'Education','Gender','Income','Race/Ethnicity'], prefix=['Age(years)', 'Education','Gender','Income','Race\Ethnicity'])

# %%
filter_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8844 entries, 56 to 38208
# Data columns (total 36 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   YearStart                                     8844 non-null   int64
#  1   LocationDesc                                  8844 non-null   object
#  2   Class                                         8844 non-null   object
#  3   Question                                      8844 non-null   object
#  4   Data_Value                                    7994 non-null   float64
#  5   Low_Confidence_Limit                          7994 non-null   float64
#  6   High_Confidence_Limit                         7994 non-null   float64
#  7   StratificationCategory1                       8844 non-null   object
#  8   Stratification1                               8844 non-null   object
# ...

# %%
filter_data1.drop(['Income_Data not reported'], axis=1, inplace=True)
filter_data1
# Out:
#        YearStart LocationDesc                  Class  \
# 56          2011      Alabama  Fruits and Vegetables
# 57          2011      Alabama  Fruits and Vegetables
# 58          2011      Alabama  Fruits and Vegetables
# 59          2011      Alabama  Fruits and Vegetables
# 60          2011      Alabama  Fruits and Vegetables
# ...          ...          ...                    ...
# 38204       2015  Puerto Rico  Fruits and Vegetables
# 38205       2015  Puerto Rico  Fruits and Vegetables
# 38206       2015  Puerto Rico  Fruits and Vegetables
# 38207       2015  Puerto Rico  Fruits and Vegetables
# 38208       2015  Puerto Rico  Fruits and Vegetables
#
#                                                 Question  Data_Value  \
# 56     Percent of adults who report consuming fruit l...        43.8
# 57     Percent of adults who report consuming fruit l...        35.4
# 58     Percent of adults who report consuming fruit l...        35.4
# ...

# %%
columns_to_fillna = ['Data_Value', 'Low_Confidence_Limit', 'High_Confidence_Limit ']

for column in columns_to_fillna:
    if filter_data1[column].dtype == 'float64' or filter_data1[column].dtype == 'int64':
        mean_value = df[column].mean()
        filter_data1[column].fillna(mean_value, inplace=True)

# %%
filter_data1
# Out:
#        YearStart LocationDesc                  Class  \
# 56          2011      Alabama  Fruits and Vegetables
# 57          2011      Alabama  Fruits and Vegetables
# 58          2011      Alabama  Fruits and Vegetables
# 59          2011      Alabama  Fruits and Vegetables
# 60          2011      Alabama  Fruits and Vegetables
# ...          ...          ...                    ...
# 38204       2015  Puerto Rico  Fruits and Vegetables
# 38205       2015  Puerto Rico  Fruits and Vegetables
# 38206       2015  Puerto Rico  Fruits and Vegetables
# 38207       2015  Puerto Rico  Fruits and Vegetables
# 38208       2015  Puerto Rico  Fruits and Vegetables
#
#                                                 Question  Data_Value  \
# 56     Percent of adults who report consuming fruit l...   43.800000
# 57     Percent of adults who report consuming fruit l...   35.400000
# 58     Percent of adults who report consuming fruit l...   35.400000
# ...

# %%
columns_to_fill = ['LocationDesc', 'Class', 'Question']

for column in columns_to_fill:
    filter_data1[column].fillna(filter_data1[column].mode()[0], inplace=True)

# %%
filter_data1['Class']
# Out:
# 56       Fruits and Vegetables
# 57       Fruits and Vegetables
# 58       Fruits and Vegetables
# 59       Fruits and Vegetables
# 60       Fruits and Vegetables
#                  ...
# 38204    Fruits and Vegetables
# 38205    Fruits and Vegetables
# 38206    Fruits and Vegetables
# 38207    Fruits and Vegetables
# 38208    Fruits and Vegetables
# Name: Class, Length: 8844, dtype: object

# %%
filter_data1['Class'] = 0
filter_data1
# Out:
#        YearStart LocationDesc  Class  \
# 56          2011      Alabama      0
# 57          2011      Alabama      0
# 58          2011      Alabama      0
# 59          2011      Alabama      0
# 60          2011      Alabama      0
# ...          ...          ...    ...
# 38204       2015  Puerto Rico      0
# 38205       2015  Puerto Rico      0
# 38206       2015  Puerto Rico      0
# 38207       2015  Puerto Rico      0
# 38208       2015  Puerto Rico      0
#
#                                                 Question  Data_Value  \
# 56     Percent of adults who report consuming fruit l...   43.800000
# 57     Percent of adults who report consuming fruit l...   35.400000
# 58     Percent of adults who report consuming fruit l...   35.400000
# 59     Percent of adults who report consuming fruit l...   36.100000
# 60     Percent of adults who report consuming fruit l...   37.400000
# ...                                                  ...         ...
# ...

# %%
classes = filter_data1['Class'].value_counts()
classes
# Out:
# 0    8844
# Name: Class, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# List of columns with categorical data that you want to label encode
categorical_columns = ['LocationDesc', 'Class', 'Question']

# Initialize a LabelEncoder object
label_encoder = LabelEncoder()

# Loop through each column and apply label encoding
for column in categorical_columns:
    filter_data1[column] = label_encoder.fit_transform(filter_data1[column])

filter_data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8844 entries, 56 to 38208
# Data columns (total 35 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   YearStart                                     8844 non-null   int64
#  1   LocationDesc                                  8844 non-null   int64
#  2   Class                                         8844 non-null   int64
#  3   Question                                      8844 non-null   int64
#  4   Data_Value                                    8844 non-null   float64
#  5   Low_Confidence_Limit                          8844 non-null   float64
#  6   High_Confidence_Limit                         8844 non-null   float64
#  7   StratificationCategory1                       8844 non-null   object
#  8   Stratification1                               8844 non-null   object
# ...

# %%
filter_data1
# Out:
#        YearStart  LocationDesc  Class  Question  Data_Value  \
# 56          2011             0      0         0   43.800000
# 57          2011             0      0         0   35.400000
# 58          2011             0      0         0   35.400000
# 59          2011             0      0         0   36.100000
# 60          2011             0      0         0   37.400000
# ...          ...           ...    ...       ...         ...
# 38204       2015            41      0         1   31.156681
# 38205       2015            41      0         1   31.156681
# 38206       2015            41      0         1   31.156681
# 38207       2015            41      0         1   31.156681
# 38208       2015            41      0         1   24.400000
#
#        Low_Confidence_Limit  High_Confidence_Limit  StratificationCategory1  \
# 56                42.100000               45.500000                   Total
# 57                33.000000               37.900000             Age (years)
# ...

# %%
filter_data1.columns
# Out:
# Index(['YearStart', 'LocationDesc', 'Class', 'Question', 'Data_Value',
#        'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'StratificationCategory1', 'Stratification1', 'Age(years)_18 - 24',
#        'Age(years)_25 - 34', 'Age(years)_35 - 44', 'Age(years)_45 - 54',
#        'Age(years)_55 - 64', 'Age(years)_65 or older',
#        'Education_College graduate', 'Education_High school graduate',
#        'Education_Less than high school',
#        'Education_Some college or technical school', 'Gender_Female',
#        'Gender_Male', 'Income_$15,000 - $24,999', 'Income_$25,000 - $34,999',
#        'Income_$35,000 - $49,999', 'Income_$50,000 - $74,999',
#        'Income_$75,000 or greater', 'Income_Less than $15,000',
#        'Race\Ethnicity_2 or more races',
#        'Race\Ethnicity_American Indian/Alaska Native', 'Race\Ethnicity_Asian',
#        'Race\Ethnicity_Hawaiian/Pacific Islander', 'Race\Ethnicity_Hispanic',
#        'Race\Ethnicity_Non-Hispanic Black',
# ...

# %%
# Selecting the relevant columns
columns_to_visualize = [
    'Question',
    'Data_Value',
    'Low_Confidence_Limit',
    'High_Confidence_Limit ',
    'Age(years)_18 - 24',
    'Age(years)_25 - 34',
    'Age(years)_35 - 44',
    'Age(years)_45 - 54',
    'Age(years)_55 - 64',
    'Age(years)_65 or older'
]

# Calculate point-biserial correlation between categorical columns and 'Data_Value'
correlation_matrix = filter_data1[columns_to_visualize].corr()

# Create a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation w.r.t Age')
plt.show()

# %%
# Selecting the relevant columns
columns_to_visualizes = [
    'Question',
    'Data_Value',
    'Low_Confidence_Limit',
    'High_Confidence_Limit ',
    'Income_$15,000 - $24,999',
    'Income_$25,000 - $34,999',
    'Income_$35,000 - $49,999',
    'Income_$50,000 - $74,999',
    'Income_$75,000 or greater',
    'Income_Less than $15,000'
]

# Calculate point-biserial correlation between categorical columns and 'Data_Value'
correlation_matrix1 = filter_data1[columns_to_visualizes].corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix1, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation w.r.t Income')
plt.show()

# %%
# Selecting the relevant columns
column_to_visualizes = [
    'Question',
    'Data_Value',
    'Low_Confidence_Limit',
    'High_Confidence_Limit ',
    'Education_College graduate',
    'Education_High school graduate',
    'Education_Less than high school',
    'Education_Some college or technical school'
]

# Calculate point-biserial correlation between categorical columns and 'Data_Value'
correlation_matrix2 = filter_data1[column_to_visualizes].corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix2, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation w.r.t Education')
plt.show()

# %%
filter_data1.isnull().sum()
# Out:
# YearStart                                       0
# LocationDesc                                    0
# Class                                           0
# Question                                        0
# Data_Value                                      0
# Low_Confidence_Limit                            0
# High_Confidence_Limit                           0
# StratificationCategory1                         0
# Stratification1                                 0
# Age(years)_18 - 24                              0
# Age(years)_25 - 34                              0
# Age(years)_35 - 44                              0
# Age(years)_45 - 54                              0
# Age(years)_55 - 64                              0
# Age(years)_65 or older                          0
# Education_College graduate                      0
# Education_High school graduate                  0
# Education_Less than high school                 0
# Education_Some college or technical school      0
# ...

# %%
# Create a boxplot for 'Low_Confidence_Limit and High_Confidence_Limit'
fig, ax = plt.subplots(1, 2, figsize=(12, 4))

sns.set_theme(style="whitegrid")
for axid, col in enumerate(["Low_Confidence_Limit", "High_Confidence_Limit "]):
    sns.boxplot(x=filter_data1[col], ax=ax[axid])

# %%
sns.scatterplot(x=filter_data1["Low_Confidence_Limit"], y=filter_data1["High_Confidence_Limit "])
# Out:
# <Axes: xlabel='Low_Confidence_Limit', ylabel='High_Confidence_Limit '>

# %%
from sklearn.model_selection import train_test_split, cross_validate, cross_val_score, GridSearchCV

# %%
whole_data = filter_data1[['YearStart', 'LocationDesc', 'Class', 'Question', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
       'Age(years)_18 - 24','Age(years)_25 - 34', 'Age(years)_35 - 44', 'Age(years)_45 - 54',
       'Age(years)_55 - 64', 'Age(years)_65 or older', 'Education_College graduate', 'Education_High school graduate',
       'Education_Less than high school', 'Education_Some college or technical school', 'Gender_Female',
       'Gender_Male', 'Income_$15,000 - $24,999', 'Income_$25,000 - $34,999', 'Income_$35,000 - $49,999', 'Income_$50,000 - $74,999',
       'Income_$75,000 or greater', 'Income_Less than $15,000', 'Race\Ethnicity_2 or more races',
       'Race\Ethnicity_American Indian/Alaska Native', 'Race\Ethnicity_Asian',
       'Race\Ethnicity_Hawaiian/Pacific Islander', 'Race\Ethnicity_Hispanic',
       'Race\Ethnicity_Non-Hispanic Black', 'Race\Ethnicity_Non-Hispanic White', 'Race\Ethnicity_Other']]

whole_data.head()
# Out:
#     YearStart  LocationDesc  Class  Question  Low_Confidence_Limit  \
# 56       2011             0      0         0                  42.1
# 57       2011             0      0         0                  33.0
# 58       2011             0      0         0                  23.0
# 59       2011             0      0         0                  33.1
# 60       2011             0      0         0                  21.6
#
#     High_Confidence_Limit   Age(years)_18 - 24  Age(years)_25 - 34  \
# 56                    45.5                   0                   0
# 57                    37.9                   0                   0
# 58                    50.2                   0                   0
# 59                    39.1                   0                   0
# 60                    56.5                   0                   0
#
#     Age(years)_35 - 44  Age(years)_45 - 54  ...  Income_$75,000 or greater  \
# 56                   0                   0  ...                          0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(whole_data, filter_data1["Data_Value"], random_state=42, test_size=0.20)

# %%
X_train
# Out:
#        YearStart  LocationDesc  Class  Question  Low_Confidence_Limit  \
# 29864       2011            46      0         0             37.500000
# 37010       2015            34      0         1             26.600000
# 8228        2011            13      0         0             32.200000
# 37428       2015            43      0         0             49.300000
# 6824        2011            10      0         1             16.000000
# ...          ...           ...    ...       ...                   ...
# 34583       2011            53      0         0             31.100000
# 31235       2011            48      0         1             14.400000
# 32554       2011            50      0         0             33.500000
# 5125        2013             7      0         0             26.892227
# 36622       2015            26      0         1             23.600000
#
#        High_Confidence_Limit   Age(years)_18 - 24  Age(years)_25 - 34  \
# ...

# %%
y_train
# Out:
# 29864    40.200000
# 37010    30.500000
# 8228     40.400000
# 37428    54.400000
# 6824     18.700000
#            ...
# 34583    44.400000
# 31235    16.400000
# 32554    37.300000
# 5125     31.156681
# 36622    28.300000
# Name: Data_Value, Length: 7075, dtype: float64

# %%
from sklearn import preprocessing


size_scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled = size_scaler.transform(X_train)
X_test_scaled = size_scaler.transform(X_test)
X_train_scaled.shape, X_test_scaled.shape
# Out:
# ((7075, 32), (1769, 32))

# %%
X_train_scaled
# Out:
# array([[-1.22960754,  1.25291225,  0.        , ..., -0.18778938,
#         -0.18576321, -0.19218195],
#        [ 1.20858566,  0.48094089,  0.        , ..., -0.18778938,
#         -0.18576321, -0.19218195],
#        [-1.22960754, -0.870009  ,  0.        , ..., -0.18778938,
#         -0.18576321, -0.19218195],
#        ...,
#        [-1.22960754,  1.51023604,  0.        , ..., -0.18778938,
#         -0.18576321, -0.19218195],
#        [-0.01051094, -1.25599468,  0.        , ..., -0.18778938,
#         -0.18576321, -0.19218195],
#        [ 1.20858566, -0.03370669,  0.        , ..., -0.18778938,
#         -0.18576321, -0.19218195]])

# %%
X_test_scaled
# Out:
# array([[-1.22960754, -0.41969237,  0.        , ..., -0.18778938,
#         -0.18576321, -0.19218195],
#        [-1.22960754, -0.16236858,  0.        , ..., -0.18778938,
#         -0.18576321, -0.19218195],
#        [-0.01051094, -0.54835426,  0.        , ..., -0.18778938,
#         -0.18576321, -0.19218195],
#        ...,
#        [ 1.20858566, -0.93433995,  0.        , ..., -0.18778938,
#         -0.18576321, -0.19218195],
#        [ 1.20858566, -0.41969237,  0.        , ..., -0.18778938,
#         -0.18576321, -0.19218195],
#        [-1.22960754,  0.99558846,  0.        , ..., -0.18778938,
#         -0.18576321, -0.19218195]])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# Models-------------------------
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline

# %%
poly_regression = Pipeline([
    ('poly_features', PolynomialFeatures(degree=2)),
    ('regressor', LinearRegression())
])

model_dict = {
    'LinearRegression': {"model": LinearRegression(), "params": {}},
    'PolynomialRegression': {"model": poly_regression, "params": {}}
}

# %%
def eval_models():
    model_results = pd.DataFrame()
    model_results['Train_RMSE'] = None
    model_results['Test_RMSE'] = None
    model_results['Train_MAE'] = None
    model_results['Test_MAE'] = None
    model_results['best_params'] = None

    best_reg_model_ours = None
    best_test_score = math.inf

    for model_name, reg_model in model_dict.items():
        classifier = GridSearchCV(reg_model['model'], reg_model['params'], n_jobs=20, verbose=0)
        classifier.fit(X_train_scaled, list(y_train))
        best_model = classifier.best_estimator_

        y_train_predicted = best_model.predict(X_train_scaled)
        train_rmse = np.sqrt(mean_squared_error(list(y_train), y_train_predicted))
        train_mae = mean_absolute_error(list(y_train), y_train_predicted)

        print(model_name, train_rmse, classifier.best_params_)

        y_predicted = best_model.predict(X_test_scaled)
        test_rmse = np.sqrt(mean_squared_error(list(y_test), y_predicted))
        test_mae = mean_absolute_error(list(y_test), y_predicted)

        if test_rmse < best_test_score:
            best_test_score = test_rmse
            best_reg_model_ours = best_model

        model_results.loc[model_name, ['Train_RMSE', 'Test_RMSE', 'Train_MAE', 'Test_MAE', 'best_params']] = [train_rmse, test_rmse, train_mae, test_mae, classifier.best_params_]

    print("Best model: ", best_model)
    # plot the prediction errors using the best model
    y_predicted = best_model.predict(X_test_scaled)
    plt.plot(list(y_test) - y_predicted, marker='o', linestyle='')

    return model_results

# %%
model_results = eval_models()
# Out:
# LinearRegression 0.3573478378351998 {}
# PolynomialRegression 0.13849891168877715 {}
# Best model:  Pipeline(steps=[('poly_features', PolynomialFeatures()),
#                 ('regressor', LinearRegression())])

# %%
model_results
# Out:
#                      Train_RMSE Test_RMSE Train_MAE  Test_MAE best_params
# LinearRegression       0.357348  0.344504  0.187323  0.181664          {}
# PolynomialRegression   0.138499    0.1241  0.072686  0.071681          {}

# %%
# NOW TRAINING THE MODEL WITH THE AGE PARAMETER

# %%
age_data = filter_data1[['YearStart', 'LocationDesc', 'Class', 'Question', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
            'Age(years)_18 - 24', 'Age(years)_25 - 34', 'Age(years)_35 - 44', 'Age(years)_45 - 54',
            'Age(years)_55 - 64', 'Age(years)_65 or older']]

age_data.head()
# Out:
#     YearStart  LocationDesc  Class  Question  Low_Confidence_Limit  \
# 56       2011             0      0         0                  42.1
# 57       2011             0      0         0                  33.0
# 58       2011             0      0         0                  23.0
# 59       2011             0      0         0                  33.1
# 60       2011             0      0         0                  21.6
#
#     High_Confidence_Limit   Age(years)_18 - 24  Age(years)_25 - 34  \
# 56                    45.5                   0                   0
# 57                    37.9                   0                   0
# 58                    50.2                   0                   0
# 59                    39.1                   0                   0
# 60                    56.5                   0                   0
#
#     Age(years)_35 - 44  Age(years)_45 - 54  Age(years)_55 - 64  \
# 56                   0                   0                   0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(age_data, filter_data1["Data_Value"], random_state=42, test_size=0.20)

# %%
X_train
# Out:
#        YearStart  LocationDesc  Class  Question  Low_Confidence_Limit  \
# 29864       2011            46      0         0             37.500000
# 37010       2015            34      0         1             26.600000
# 8228        2011            13      0         0             32.200000
# 37428       2015            43      0         0             49.300000
# 6824        2011            10      0         1             16.000000
# ...          ...           ...    ...       ...                   ...
# 34583       2011            53      0         0             31.100000
# 31235       2011            48      0         1             14.400000
# 32554       2011            50      0         0             33.500000
# 5125        2013             7      0         0             26.892227
# 36622       2015            26      0         1             23.600000
#
#        High_Confidence_Limit   Age(years)_18 - 24  Age(years)_25 - 34  \
# ...

# %%
y_train
# Out:
# 29864    40.200000
# 37010    30.500000
# 8228     40.400000
# 37428    54.400000
# 6824     18.700000
#            ...
# 34583    44.400000
# 31235    16.400000
# 32554    37.300000
# 5125     31.156681
# 36622    28.300000
# Name: Data_Value, Length: 7075, dtype: float64

# %%
size_scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled = size_scaler.transform(X_train)
X_test_scaled = size_scaler.transform(X_test)
X_train_scaled.shape, X_test_scaled.shape
# Out:
# ((7075, 12), (1769, 12))

# %%
X_train_scaled
# Out:
# array([[-1.22960754,  1.25291225,  0.        , ..., -0.1917862 ,
#         -0.1941503 , -0.193758  ],
#        [ 1.20858566,  0.48094089,  0.        , ..., -0.1917862 ,
#         -0.1941503 , -0.193758  ],
#        [-1.22960754, -0.870009  ,  0.        , ..., -0.1917862 ,
#         -0.1941503 , -0.193758  ],
#        ...,
#        [-1.22960754,  1.51023604,  0.        , ..., -0.1917862 ,
#         -0.1941503 , -0.193758  ],
#        [-0.01051094, -1.25599468,  0.        , ..., -0.1917862 ,
#         -0.1941503 , -0.193758  ],
#        [ 1.20858566, -0.03370669,  0.        , ..., -0.1917862 ,
#         -0.1941503 , -0.193758  ]])

# %%
X_test_scaled
# Out:
# array([[-1.22960754, -0.41969237,  0.        , ...,  5.21413953,
#         -0.1941503 , -0.193758  ],
#        [-1.22960754, -0.16236858,  0.        , ..., -0.1917862 ,
#         -0.1941503 , -0.193758  ],
#        [-0.01051094, -0.54835426,  0.        , ..., -0.1917862 ,
#         -0.1941503 , -0.193758  ],
#        ...,
#        [ 1.20858566, -0.93433995,  0.        , ..., -0.1917862 ,
#         -0.1941503 , -0.193758  ],
#        [ 1.20858566, -0.41969237,  0.        , ..., -0.1917862 ,
#         -0.1941503 , -0.193758  ],
#        [-1.22960754,  0.99558846,  0.        , ..., -0.1917862 ,
#         -0.1941503 , -0.193758  ]])

# %%
poly_regression = Pipeline([
    ('poly_features', PolynomialFeatures(degree=2)),
    ('regressor', LinearRegression())
])

model_dict = {
    'LinearRegression': {"model": LinearRegression(), "params": {}},
    'PolynomialRegression': {"model": poly_regression, "params": {}}
}

# %%
def eval_models():
    model_results = pd.DataFrame()
    model_results['Train_RMSE'] = None
    model_results['Test_RMSE'] = None
    model_results['Train_MAE'] = None
    model_results['Test_MAE'] = None
    model_results['best_params'] = None

    best_reg_model_ours = None
    best_test_score = math.inf

    for model_name, reg_model in model_dict.items():
        classifier = GridSearchCV(reg_model['model'], reg_model['params'], n_jobs=20, verbose=0)
        classifier.fit(X_train_scaled, list(y_train))
        best_model = classifier.best_estimator_

        y_train_predicted = best_model.predict(X_train_scaled)
        train_rmse = np.sqrt(mean_squared_error(list(y_train), y_train_predicted))
        train_mae = mean_absolute_error(list(y_train), y_train_predicted)

        print(model_name, train_rmse, classifier.best_params_)

        y_predicted = best_model.predict(X_test_scaled)
        test_rmse = np.sqrt(mean_squared_error(list(y_test), y_predicted))
        test_mae = mean_absolute_error(list(y_test), y_predicted)

        if test_rmse < best_test_score:
            best_test_score = test_rmse
            best_reg_model_ours = best_model

        model_results.loc[model_name, ['Train_RMSE', 'Test_RMSE', 'Train_MAE', 'Test_MAE', 'best_params']] = [train_rmse, test_rmse, train_mae, test_mae, classifier.best_params_]

    print("Best model: ", best_model)
    # plot the prediction errors using the best model
    y_predicted = best_model.predict(X_test_scaled)
    plt.plot(list(y_test) - y_predicted, marker='o', linestyle='')

    return model_results

# %%
model_results = eval_models()
# Out:
# LinearRegression 0.3672205039708981 {}
# PolynomialRegression 0.15397058061390648 {}
# Best model:  Pipeline(steps=[('poly_features', PolynomialFeatures()),
#                 ('regressor', LinearRegression())])

# %%
model_results
# Out:
#                      Train_RMSE Test_RMSE Train_MAE  Test_MAE best_params
# LinearRegression       0.367221  0.348036  0.193171  0.185799          {}
# PolynomialRegression   0.153971  0.134516  0.087087  0.084216          {}

# %%
# NOW TRAINING THE MODEL WITH THE Income PARAMETER

# %%
income_data = filter_data1[['YearStart', 'LocationDesc', 'Class', 'Question', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
            'Income_$15,000 - $24,999', 'Income_$25,000 - $34,999','Income_$35,000 - $49,999',
            'Income_$50,000 - $74,999', 'Income_$75,000 or greater', 'Income_Less than $15,000']]

income_data.head()
# Out:
#     YearStart  LocationDesc  Class  Question  Low_Confidence_Limit  \
# 56       2011             0      0         0                  42.1
# 57       2011             0      0         0                  33.0
# 58       2011             0      0         0                  23.0
# 59       2011             0      0         0                  33.1
# 60       2011             0      0         0                  21.6
#
#     High_Confidence_Limit   Income_$15,000 - $24,999  \
# 56                    45.5                         0
# 57                    37.9                         0
# 58                    50.2                         0
# 59                    39.1                         0
# 60                    56.5                         0
#
#     Income_$25,000 - $34,999  Income_$35,000 - $49,999  \
# 56                         0                         0
# 57                         0                         0
# 58                         0                         0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(income_data, filter_data1["Data_Value"], random_state=42, test_size=0.20)

# %%
X_train
# Out:
#        YearStart  LocationDesc  Class  Question  Low_Confidence_Limit  \
# 29864       2011            46      0         0             37.500000
# 37010       2015            34      0         1             26.600000
# 8228        2011            13      0         0             32.200000
# 37428       2015            43      0         0             49.300000
# 6824        2011            10      0         1             16.000000
# ...          ...           ...    ...       ...                   ...
# 34583       2011            53      0         0             31.100000
# 31235       2011            48      0         1             14.400000
# 32554       2011            50      0         0             33.500000
# 5125        2013             7      0         0             26.892227
# 36622       2015            26      0         1             23.600000
#
#        High_Confidence_Limit   Income_$15,000 - $24,999  \
# 29864               42.900000                         0
# ...

# %%
y_train
# Out:
# 29864    40.200000
# 37010    30.500000
# 8228     40.400000
# 37428    54.400000
# 6824     18.700000
#            ...
# 34583    44.400000
# 31235    16.400000
# 32554    37.300000
# 5125     31.156681
# 36622    28.300000
# Name: Data_Value, Length: 7075, dtype: float64

# %%
size_scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled = size_scaler.transform(X_train)
X_test_scaled = size_scaler.transform(X_test)
X_train_scaled.shape, X_test_scaled.shape
# Out:
# ((7075, 12), (1769, 12))

# %%
X_train_scaled
# Out:
# array([[-1.22960754,  1.25291225,  0.        , ..., -0.18738566,
#         -0.18859458, -0.1917862 ],
#        [ 1.20858566,  0.48094089,  0.        , ..., -0.18738566,
#         -0.18859458, -0.1917862 ],
#        [-1.22960754, -0.870009  ,  0.        , ..., -0.18738566,
#         -0.18859458, -0.1917862 ],
#        ...,
#        [-1.22960754,  1.51023604,  0.        , ..., -0.18738566,
#         -0.18859458, -0.1917862 ],
#        [-0.01051094, -1.25599468,  0.        , ..., -0.18738566,
#         -0.18859458, -0.1917862 ],
#        [ 1.20858566, -0.03370669,  0.        , ..., -0.18738566,
#         -0.18859458, -0.1917862 ]])

# %%
X_test_scaled
# Out:
# array([[-1.22960754, -0.41969237,  0.        , ..., -0.18738566,
#         -0.18859458, -0.1917862 ],
#        [-1.22960754, -0.16236858,  0.        , ..., -0.18738566,
#         -0.18859458, -0.1917862 ],
#        [-0.01051094, -0.54835426,  0.        , ..., -0.18738566,
#         -0.18859458, -0.1917862 ],
#        ...,
#        [ 1.20858566, -0.93433995,  0.        , ..., -0.18738566,
#         -0.18859458, -0.1917862 ],
#        [ 1.20858566, -0.41969237,  0.        , ..., -0.18738566,
#         -0.18859458, -0.1917862 ],
#        [-1.22960754,  0.99558846,  0.        , ..., -0.18738566,
#         -0.18859458, -0.1917862 ]])

# %%
poly_regression = Pipeline([
    ('poly_features', PolynomialFeatures(degree=2)),
    ('regressor', LinearRegression())
])

model_dict = {
    'LinearRegression': {"model": LinearRegression(), "params": {}},
    'PolynomialRegression': {"model": poly_regression, "params": {}}
}

# %%
def eval_models():
    model_results = pd.DataFrame()
    model_results['Train_RMSE'] = None
    model_results['Test_RMSE'] = None
    model_results['Train_MAE'] = None
    model_results['Test_MAE'] = None
    model_results['best_params'] = None

    best_reg_model_ours = None
    best_test_score = math.inf

    for model_name, reg_model in model_dict.items():
        classifier = GridSearchCV(reg_model['model'], reg_model['params'], n_jobs=20, verbose=0)
        classifier.fit(X_train_scaled, list(y_train))
        best_model = classifier.best_estimator_

        y_train_predicted = best_model.predict(X_train_scaled)
        train_rmse = np.sqrt(mean_squared_error(list(y_train), y_train_predicted))
        train_mae = mean_absolute_error(list(y_train), y_train_predicted)

        print(model_name, train_rmse, classifier.best_params_)

        y_predicted = best_model.predict(X_test_scaled)
        test_rmse = np.sqrt(mean_squared_error(list(y_test), y_predicted))
        test_mae = mean_absolute_error(list(y_test), y_predicted)

        if test_rmse < best_test_score:
            best_test_score = test_rmse
            best_reg_model_ours = best_model

        model_results.loc[model_name, ['Train_RMSE', 'Test_RMSE', 'Train_MAE', 'Test_MAE', 'best_params']] = [train_rmse, test_rmse, train_mae, test_mae, classifier.best_params_]

    print("Best model: ", best_model)
    # plot the prediction errors using the best model
    y_predicted = best_model.predict(X_test_scaled)
    plt.plot(list(y_test) - y_predicted, marker='o', linestyle='')

    return model_results

# %%
model_results = eval_models()
# Out:
# LinearRegression 0.36641608060937975 {}
# PolynomialRegression 0.1525392228928282 {}
# Best model:  Pipeline(steps=[('poly_features', PolynomialFeatures()),
#                 ('regressor', LinearRegression())])

# %%
model_results
# Out:
#                      Train_RMSE Test_RMSE Train_MAE  Test_MAE best_params
# LinearRegression       0.366416  0.347447  0.193242   0.18524          {}
# PolynomialRegression   0.152539  0.134957  0.085278  0.084423          {}

# %%
# NOW TRAINING THE MODEL WITH THE Education PARAMETER

# %%
education_data = filter_data1[['YearStart', 'LocationDesc', 'Class', 'Question', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
            'Education_College graduate', 'Education_High school graduate','Education_Less than high school',
            'Education_Some college or technical school']]

education_data.head()
# Out:
#     YearStart  LocationDesc  Class  Question  Low_Confidence_Limit  \
# 56       2011             0      0         0                  42.1
# 57       2011             0      0         0                  33.0
# 58       2011             0      0         0                  23.0
# 59       2011             0      0         0                  33.1
# 60       2011             0      0         0                  21.6
#
#     High_Confidence_Limit   Education_College graduate  \
# 56                    45.5                           0
# 57                    37.9                           0
# 58                    50.2                           0
# 59                    39.1                           1
# 60                    56.5                           0
#
#     Education_High school graduate  Education_Less than high school  \
# 56                               0                                0
# 57                               0                                0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(education_data, filter_data1["Data_Value"], random_state=42, test_size=0.20)

# %%
X_train
# Out:
#        YearStart  LocationDesc  Class  Question  Low_Confidence_Limit  \
# 29864       2011            46      0         0             37.500000
# 37010       2015            34      0         1             26.600000
# 8228        2011            13      0         0             32.200000
# 37428       2015            43      0         0             49.300000
# 6824        2011            10      0         1             16.000000
# ...          ...           ...    ...       ...                   ...
# 34583       2011            53      0         0             31.100000
# 31235       2011            48      0         1             14.400000
# 32554       2011            50      0         0             33.500000
# 5125        2013             7      0         0             26.892227
# 36622       2015            26      0         1             23.600000
#
#        High_Confidence_Limit   Education_College graduate  \
# 29864               42.900000                           0
# ...

# %%
y_train
# Out:
# 29864    40.200000
# 37010    30.500000
# 8228     40.400000
# 37428    54.400000
# 6824     18.700000
#            ...
# 34583    44.400000
# 31235    16.400000
# 32554    37.300000
# 5125     31.156681
# 36622    28.300000
# Name: Data_Value, Length: 7075, dtype: float64

# %%
size_scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled = size_scaler.transform(X_train)
X_test_scaled = size_scaler.transform(X_test)
X_train_scaled.shape, X_test_scaled.shape
# Out:
# ((7075, 10), (1769, 10))

# %%
X_train_scaled
# Out:
# array([[-1.22960754,  1.25291225,  0.        , ..., -0.18819235,
#         -0.19218195, -0.19454192],
#        [ 1.20858566,  0.48094089,  0.        , ..., -0.18819235,
#          5.20340243, -0.19454192],
#        [-1.22960754, -0.870009  ,  0.        , ..., -0.18819235,
#         -0.19218195, -0.19454192],
#        ...,
#        [-1.22960754,  1.51023604,  0.        , ..., -0.18819235,
#         -0.19218195, -0.19454192],
#        [-0.01051094, -1.25599468,  0.        , ..., -0.18819235,
#         -0.19218195, -0.19454192],
#        [ 1.20858566, -0.03370669,  0.        , ..., -0.18819235,
#         -0.19218195, -0.19454192]])

# %%
X_test_scaled
# Out:
# array([[-1.22960754, -0.41969237,  0.        , ..., -0.18819235,
#         -0.19218195, -0.19454192],
#        [-1.22960754, -0.16236858,  0.        , ..., -0.18819235,
#         -0.19218195, -0.19454192],
#        [-0.01051094, -0.54835426,  0.        , ...,  5.31371219,
#         -0.19218195, -0.19454192],
#        ...,
#        [ 1.20858566, -0.93433995,  0.        , ..., -0.18819235,
#         -0.19218195,  5.14028021],
#        [ 1.20858566, -0.41969237,  0.        , ..., -0.18819235,
#         -0.19218195, -0.19454192],
#        [-1.22960754,  0.99558846,  0.        , ..., -0.18819235,
#         -0.19218195, -0.19454192]])

# %%
poly_regression = Pipeline([
    ('poly_features', PolynomialFeatures(degree=2)),
    ('regressor', LinearRegression())
])

model_dict = {
    'LinearRegression': {"model": LinearRegression(), "params": {}},
    'PolynomialRegression': {"model": poly_regression, "params": {}}
}

# %%
def eval_models():
    model_results = pd.DataFrame()
    model_results['Train_RMSE'] = None
    model_results['Test_RMSE'] = None
    model_results['Train_MAE'] = None
    model_results['Test_MAE'] = None
    model_results['best_params'] = None

    best_reg_model_ours = None
    best_test_score = math.inf

    for model_name, reg_model in model_dict.items():
        classifier = GridSearchCV(reg_model['model'], reg_model['params'], n_jobs=20, verbose=0)
        classifier.fit(X_train_scaled, list(y_train))
        best_model = classifier.best_estimator_

        y_train_predicted = best_model.predict(X_train_scaled)
        train_rmse = np.sqrt(mean_squared_error(list(y_train), y_train_predicted))
        train_mae = mean_absolute_error(list(y_train), y_train_predicted)

        print(model_name, train_rmse, classifier.best_params_)

        y_predicted = best_model.predict(X_test_scaled)
        test_rmse = np.sqrt(mean_squared_error(list(y_test), y_predicted))
        test_mae = mean_absolute_error(list(y_test), y_predicted)

        if test_rmse < best_test_score:
            best_test_score = test_rmse
            best_reg_model_ours = best_model

        model_results.loc[model_name, ['Train_RMSE', 'Test_RMSE', 'Train_MAE', 'Test_MAE', 'best_params']] = [train_rmse, test_rmse, train_mae, test_mae, classifier.best_params_]

    print("Best model: ", best_model)
    # plot the prediction errors using the best model
    y_predicted = best_model.predict(X_test_scaled)
    plt.plot(list(y_test) - y_predicted, marker='o', linestyle='')

    return model_results

# %%
model_results = eval_models()
# Out:
# LinearRegression 0.3668508976262953 {}
# PolynomialRegression 0.15529962773144937 {}
# Best model:  Pipeline(steps=[('poly_features', PolynomialFeatures()),
#                 ('regressor', LinearRegression())])

# %%
model_results
# Out:
#                      Train_RMSE Test_RMSE Train_MAE  Test_MAE best_params
# LinearRegression       0.366851  0.347902  0.195158  0.188141          {}
# PolynomialRegression     0.1553  0.137219  0.089214  0.087084          {}
